# %% [markdown]
# ![1_TTr3gHRr-mCQYt-f66gs_g.png](data:image/png;base64,...)

# %% [markdown]
# #Initial public offering(IPO)
#
# According to Wikipedia, An initial public offering or stock launch is a public offering in which shares of a company are sold to institutional investors and usually also retail investors. An IPO is typically underwritten by one or more investment banks, who also arrange for the shares to be listed on one or more stock exchanges.

# %%
#for mathematical computation

import numpy as np
import pandas as pd
import scipy.stats as stats

#for data visualization

import seaborn as sns
import matplotlib.pyplot as plt
import plotly
import plotly.express as px
from matplotlib.pyplot import figure

% matplotlib inline

# %%
df = pd.read_csv("/content/IPO.csv", encoding='latin-1')
df.head()
# Out:
#        Date         IPO_Name  Issue_Size(crores)     QIB     HNI     RII  \
# 0  26-11-21  Tarsons Product             1030.22    1.06    3.40    2.49
# 1  23-11-21      Latent View              622.11  145.48  850.66  119.44
# 2  18-11-21   Sapphire Foods             2073.00    3.11    2.34    5.25
# 3  18-11-21    One 97(Paytm)            18915.90    2.79    0.24    1.66
# 4  15-11-21  SJS Enterprises              816.57    1.42    2.32    1.38
#
#    Issue_price  Listing_Open  Listing_Close  Listing_Gains(%)       CMP  \
# 0        662.0         700.0         840.00             26.89    641.45
# 1        197.0         530.0         488.60            148.02    639.85
# 2       1180.0        1311.0        1216.05              3.06  1,048.05
# 3       2150.0        1955.0        1564.15            -27.25  1,655.00
# 4        542.0         514.0         509.85             -5.93    441.05
#
#    Current_gains
# 0          -3.10
# 1         224.80
# 2         -11.18
# 3         -23.02
# 4         -18.63

# %% [markdown]
# We have the IPO Name, IPO issue size, price of the open listing, listing close price, the current market price of each IPO, current gains in percentage, QIB, HNI, and RII.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 288 entries, 0 to 287
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                288 non-null    object
#  1   IPO_Name            288 non-null    object
#  2   Issue_Size(crores)  288 non-null    float64
#  3   QIB                 288 non-null    float64
#  4   HNI                 288 non-null    float64
#  5   RII                 288 non-null    float64
#  6   Issue_price         288 non-null    float64
#  7   Listing_Open        288 non-null    float64
#  8   Listing_Close       288 non-null    float64
#  9   Listing_Gains(%)    288 non-null    float64
#  10  CMP                 288 non-null    object
#  11  Current_gains       286 non-null    float64
# dtypes: float64(9), object(3)
# memory usage: 27.1+ KB

# %%
df.describe()
# Out:
#        Issue_Size(crores)         QIB         HNI         RII  Issue_price  \
# count          288.000000  288.000000  288.000000  288.000000   288.000000
# mean          1118.383750   24.834687   71.413646    8.341181   368.913194
# std           2160.932743   37.837647  142.500596   14.159700   361.287606
# min              0.000000    0.000000    0.000000    0.000000     0.000000
# 25%            156.142500    1.147500    1.210000    1.367500   113.750000
# 50%            474.000000    4.810000    5.075000    3.405000   242.500000
# 75%           1049.480000   35.492500   73.295000    8.535000   522.500000
# max          18915.900000  176.850000  958.070000  119.440000  2150.000000
#
#        Listing_Open  Listing_Close  Listing_Gains(%)  Current_gains
# count    288.000000     288.000000        288.000000     286.000000
# mean     438.374653     396.502917          5.993056      65.616573
# std      458.703932     439.609061         49.354577     261.408128
# min        9.500000       1.570000        -97.150000     -99.930000
# 25%      125.200000     104.112500        -11.340000     -73.785000
# 50%      272.200000     234.555000          2.315000      -1.800000
# 75%      600.000000     584.975000         25.780000     114.397500
# max     2725.000000    3118.650000        270.400000    2478.690000

# %% [markdown]
# ##Heatmap

# %%
f,ax = plt.subplots(figsize=(14,10))
sns.heatmap(df.corr(), annot=True, fmt=".2f", ax=ax)
plt.show()

# %% [markdown]
# - High Net-worth Individual(HNI) is very positively correlated to Qualified institutional buyer (QIB)
#
# - Retail individual investor (RII) is very positively correlated to HNI.
#
# - The issue price is highly positively correlated to Listing open and listing close.

# %% [markdown]
# ##Data cleaning

# %%
date = df.Date.str.split('-', expand =True)
df['year'] = date[2]
df['month'] = date[1]
df['day'] = date[0]

df.year = pd.to_numeric(df.year)
df.month = pd.to_numeric(df.month)
df.day = pd.to_numeric(df.day)

# %% [markdown]
# I just want to get a separate column for the year, date, and month of IPO launch. To do that, I wrote the above code. Now, our data is a little bit changed. When you see the top 5 data then you will notice that we have 3 new columns.

# %%
df.head()
# Out:
#        Date         IPO_Name  Issue_Size(crores)     QIB     HNI     RII  \
# 0  26-11-21  Tarsons Product             1030.22    1.06    3.40    2.49
# 1  23-11-21      Latent View              622.11  145.48  850.66  119.44
# 2  18-11-21   Sapphire Foods             2073.00    3.11    2.34    5.25
# 3  18-11-21    One 97(Paytm)            18915.90    2.79    0.24    1.66
# 4  15-11-21  SJS Enterprises              816.57    1.42    2.32    1.38
#
#    Issue_price  Listing_Open  Listing_Close  Listing_Gains(%)       CMP  \
# 0        662.0         700.0         840.00             26.89    641.45
# 1        197.0         530.0         488.60            148.02    639.85
# 2       1180.0        1311.0        1216.05              3.06  1,048.05
# 3       2150.0        1955.0        1564.15            -27.25  1,655.00
# 4        542.0         514.0         509.85             -5.93    441.05
#
#    Current_gains  year  month  day
# 0          -3.10    21     11   26
# 1         224.80    21     11   23
# 2         -11.18    21     11   18
# 3         -23.02    21     11   18
# 4         -18.63    21     11   15

# %% [markdown]
# ##Year-wise IPO launch

# %%
fig1 = px.pie(df, names='year')
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e4093530-cbaa-497c-ba96-a2943e1d6b02" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e4093530-cbaa-497c-ba96-a2943e1d6b02")) {                    Plotly.newPlot(                        "e4093530-cbaa-497c-ba96-a2943e1d6b02",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"year=%{label}<extra></extra>","labels":[21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,21,20,20,20,20,20,20,20,20,20,20,20,20,20,19,19,19,19,19,19,19,19,19,19,19,19,19,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,18,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,17,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,15,14,14,14,14,14,13,13,12,12,12,12,12,12,12,12,12,12,12,11,11,11,11,11,11,11,11,11,11,11,11,11,11,11,11,11,11,11,11,11,11,11,11,11,11,11,11,11,11,11,11,11,11,11,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10],"legendgroup":"","name":"","showlegend":true,"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"c ...

# %% [markdown]
# After the year 2010, the year 2021 registers the most launch of IPOs in India. Some experts say that more IPOs hit the market when the market is very bullish. We all know that right now Indian Stock Market is very bullish.

# %% [markdown]
# ##Relation of Month with IPOs launch

# %%
fig2 = px.pie(df, names='month')
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a33173b7-ea34-4ac5-b4d4-40054bb19bbb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a33173b7-ea34-4ac5-b4d4-40054bb19bbb")) {                    Plotly.newPlot(                        "a33173b7-ea34-4ac5-b4d4-40054bb19bbb",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"month=%{label}<extra></extra>","labels":[11,11,11,11,11,11,11,11,11,10,10,9,9,9,9,8,8,8,8,8,8,8,8,8,7,7,7,7,7,7,6,6,6,5,4,4,3,3,3,3,3,3,3,3,3,2,2,2,2,2,1,1,12,12,11,11,10,10,10,10,10,9,9,7,3,12,12,12,10,8,7,5,4,4,4,3,2,2,10,8,7,7,7,5,4,4,3,3,3,3,2,2,1,1,1,12,12,12,11,11,11,11,10,10,10,10,10,9,9,9,9,9,9,8,8,7,7,7,6,6,6,6,5,5,5,4,3,3,3,2,12,12,11,11,10,10,9,9,9,8,8,8,8,7,7,7,5,5,5,4,4,2,2,2,1,12,12,11,11,11,9,9,9,9,9,8,8,7,5,5,5,4,4,4,3,12,10,9,9,5,6,4,12,12,12,12,7,5,5,4,4,3,3,11,10,10,10,10,10,10,9,9,9,9,8,8,8,7,7,7,7,6,6,5,5,5,5,5,5,5,4,3,3,3,3,3,2,1,12,12,12,12,12,11,11,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,10,9,9,8,8,8,7,7,7,7,5,5,5,5,5,5,4,4,4,4,4,3,3,3,3,3,3,2,2,2,2,2,2,2,2,2],"legendgroup":"","name":"","showlegend":true,"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555 ...

# %% [markdown]
# October has the highest number of IPOs launched. But the month doesn't tell anything more specific. The listing of IPO is almost equal in each month except January and June.

# %% [markdown]
# ##WordCloud

# %%
from wordcloud import WordCloud
wordCloud = WordCloud().generate(' '.join(df.IPO_Name))

plt.figure(figsize=(15,7))
plt.axis('off')
plt.imshow(wordCloud, interpolation='bilinear')
plt.show()

# %% [markdown]
# We use the word cloud to display the visuals of text data. Word Clouds display the most prominent or frequent words in a body of text.

# %% [markdown]
# ##Top gainers in Percentage at the time of Listing.

# %%
top_gainer = df.groupby('IPO_Name').sum().sort_values('Listing_Gains(%)', ascending=False).head(20)
top_gainer = top_gainer.reset_index()
px.bar(x='IPO_Name', y ="Listing_Gains(%)", data_frame=top_gainer)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="03ba69f9-7a12-40f9-be3b-b7c732a407a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03ba69f9-7a12-40f9-be3b-b7c732a407a0")) {                    Plotly.newPlot(                        "03ba69f9-7a12-40f9-be3b-b7c732a407a0",                        [{"alignmentgroup":"True","hovertemplate":"IPO_Name=%{x}<br>Listing_Gains(%)=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Sigachi Ind","Paras Defence","Birla Pacific","Salasar Techno ","Latent View","Astron Paper & ","Burger King","Happiest Minds ","Avenue Supermar","Tatva Chintan","Indigo Paints","G R Infra","Bectors Food","Career Point","FSN E-Co(Nykaa)","PG Electroplast","MTAR Tech","Route","Bedmutha Ind","Clean Science"],"xaxis":"x","y":[270.4,185.0,153.5,151.94,148.02,139.4,130.67,123.49,114.3,113.32,109.31,108.7,106.79,103.98,96.15,96.02,88.22,86.03,77.25,76.13],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a" ...

# %% [markdown]
# Sigachi Ind listed with whooping 270.4% of the gain. I mean that’s huge. Paras defence also opens with a gain of 185%. If you got allotted to any of these stocks then let me know in the comment section. Let’s know more about Sigachi Ind:

# %%
x = df[df['IPO_Name'] == 'Sigachi Ind']
x
# Out:
#        Date     IPO_Name  Issue_Size(crores)    QIB    HNI    RII  \
# 6  15-11-21  Sigachi Ind                 0.0  42.15  78.82  41.26
#
#    Issue_price  Listing_Open  Listing_Close  Listing_Gains(%)     CMP  \
# 6        163.0         575.0         603.75             270.4  429.35
#
#    Current_gains  year  month  day
# 6          163.4    21     11   15

# %% [markdown]
# It is launched on 15th November 2021. How I missed that. Okay, I am not crying :( The issued price of this IPO was Rs. 163. It opened at Rs. 575 and closes at Rs. 603.75.

# %% [markdown]
# ##Top Losers in Percentage at the time of Listing.

# %%
top_loser = df.groupby('IPO_Name').sum().sort_values('Listing_Gains(%)', ascending=True).head(20)
top_loser = top_loser.reset_index()
px.bar(x='IPO_Name', y ="Listing_Gains(%)", data_frame=top_loser)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c8e4a144-99cb-4326-af33-41fa28d82127" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8e4a144-99cb-4326-af33-41fa28d82127")) {                    Plotly.newPlot(                        "c8e4a144-99cb-4326-af33-41fa28d82127",                        [{"alignmentgroup":"True","hovertemplate":"IPO_Name=%{x}<br>Listing_Gains(%)=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["VKS Projects","IEX","Inventure Grow","NBCC (India)","BS Limited","Goenka Diamond","Aqua Logistics","Gyscoal Alloys","Kridhan Infra","Setubandhan Inf","Ujaas Energy","Prakash Steelag","Hathway Cable","Music Broadcast","Man Infra","PNC Infratech","Fineotex Chem","Laurus Labs","Ashoka Buildcon","Bajaj Consumer "],"xaxis":"x","y":[-97.15,-96.71,-95.56,-93.9,-92.37,-90.53,-88.88,-88.51,-87.69,-83.37,-82.92,-82.91,-82.68,-82.07,-81.58,-80.94,-79.87,-77.55,-77.37,-77.02],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777 ...

# %% [markdown]
# VKS Projects are listed on the Indian Stock Market with a loss of 97.15%. I hope these IPOs were not allotted to you.
#
# If you want to know more about VKS projects then you can do this in the following way:

# %%
x2 = df[df['IPO_Name'] == 'VKS Projects']
x2
# Out:
#          Date      IPO_Name  Issue_Size(crores)   QIB   HNI   RII  \
# 186  18-07-12  VKS Projects                55.0  1.15  0.38  1.13
#
#      Issue_price  Listing_Open  Listing_Close  Listing_Gains(%)   CMP  \
# 186         55.0          55.8           1.57            -97.15  0.04
#
#      Current_gains  year  month  day
# 186         -99.93    12      7   18

# %% [markdown]
# ##Current Top Gainers

# %%
current_top_gainers = df.groupby('IPO_Name').sum().sort_values('Current_gains', ascending=False).head(20)
current_top_gainers = current_top_gainers.reset_index()
px.bar(x='IPO_Name', y ="Current_gains", data_frame=current_top_gainers)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="61507cd6-5704-4fe1-91c7-bfa4f669ac12" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61507cd6-5704-4fe1-91c7-bfa4f669ac12")) {                    Plotly.newPlot(                        "61507cd6-5704-4fe1-91c7-bfa4f669ac12",                        [{"alignmentgroup":"True","hovertemplate":"IPO_Name=%{x}<br>Current_gains=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Jubilant Food","Thangamayil","Avenue Supermar","Persistent","CDSL","L&T Infotech","Muthoot Finance","Happiest Minds ","Indiamart Inter","Dr Lal PathLab","L&T Technology","Xelpmoc Design ","Route","TeamLease Ser.","Cantabil Retail","Rushil Decor","Fine Organics","Sheela Foam","Paras Defence","Prince Pipes"],"xaxis":"x","y":[2478.69,1718.53,1479.03,1279.31,929.53,839.27,751.26,708.67,629.53,576.55,519.6,484.47,405.13,404.4,402.96,386.74,370.96,352.02,328.54,316.94],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.77777777777777 ...

# %% [markdown]
# Jubilant Food tops the chart with a whopping 2578% gain. It was listed in the year 2010. If you are a long-term investor then this chart is for you.

# %%
x3 = df[df['IPO_Name'] == 'Jubilant Food']
x3
# Out:
#          Date       IPO_Name  Issue_Size(crores)    QIB    HNI   RII  \
# 286  08-02-10  Jubilant Food               328.7  59.39  51.95  3.79
#
#      Issue_price  Listing_Open  Listing_Close  Listing_Gains(%)       CMP  \
# 286        145.0         160.0          114.5            -21.03  3,739.10
#
#      Current_gains  year  month  day
# 286        2478.69    10      2    8

# %% [markdown]
# ##Company’s IPO size (in crores)

# %%
issue_size = df.groupby('IPO_Name').sum().sort_values('Issue_Size(crores)', ascending=False).head(20)
issue_size = issue_size.reset_index()
px.bar(x='IPO_Name', y ="Issue_Size(crores)", data_frame=issue_size)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ff44af68-91b2-4f2f-829c-deb686fce99c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff44af68-91b2-4f2f-829c-deb686fce99c")) {                    Plotly.newPlot(                        "ff44af68-91b2-4f2f-829c-deb686fce99c",                        [{"alignmentgroup":"True","hovertemplate":"IPO_Name=%{x}<br>Issue_Size(crores)=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["One 97(Paytm)","Coal India","General Insuran","SBI Card","Zomato","HDFC Life","SBI Life Insura","PowerGrid InvIT","Gland","PB Fintech","ICICI Prudentia","ICICI Lombard ","Sona BLW","FSN E-Co(Nykaa)","Nuvoco Vistas","Embassy Office","IRFC","INDUS TOWERS","Bandhan Bank","Hindustan Aeron"],"xaxis":"x","y":[18915.9,15475.0,11372.0,10286.2,9375.0,8695.01,8400.0,7734.99,6479.55,6273.5,6057.0,5700.94,5550.0,5375.0,5089.29,4750.0,4633.0,4533.6,4473.0,4229.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9 ...

# %% [markdown]
# Paytm IPO was the most hyped IPO I have ever seen. But unfortunately, it didn't go well. The IPO size of coal India is also huge. But there is no future in coal. So, if you are an investor then you have to keep this in your mind.

# %% [markdown]
# ##IPO Listed in the year 2021

# %%
x4 = df[df['year'] == 21]
x4
# Out:
#         Date         IPO_Name  Issue_Size(crores)     QIB     HNI     RII  \
# 0   26-11-21  Tarsons Product             1030.22    1.06    3.40    2.49
# 1   23-11-21      Latent View              622.11  145.48  850.66  119.44
# 2   18-11-21   Sapphire Foods             2073.00    3.11    2.34    5.25
# 3   18-11-21    One 97(Paytm)            18915.90    2.79    0.24    1.66
# 4   15-11-21  SJS Enterprises              816.57    1.42    2.32    1.38
# 5   15-11-21       PB Fintech             6273.50    9.83    2.58    1.67
# 6   15-11-21      Sigachi Ind                0.00   42.15   78.82   41.26
# 7   12-11-21    Fino Payments             1209.00    1.65    0.21    5.92
# 8   10-11-21  FSN E-Co(Nykaa)             5375.00   91.18  112.02   12.24
# 9   11-10-21         ABSL AMC             2768.00    4.10    2.60    1.68
# 10  01-10-21    Paras Defence              181.13   90.48  435.14   61.42
# 11  24-09-21      Sansera Eng             1282.00   26.47   11.37    3.15
# 12  14-09-21     AMI Organics              571.96   86.64  154.81   13.36
# 13  14-09-21  Vijaya Diagnost             1895.04   13.07    1.32    1.09
# 14  06-09-21      APTUS VALUE             2790.00   32.41   33.91    1.35
# 15  24-08-21  CHEMPLAST SANMA             3929.91    2.70    1.03    2.29
# 16  23-08-21    Nuvoco Vistas             5089.29    0.10    0.02    0.24
# 17  20-08-21    CarTrade Tech             2998.00    0.55    0.09    0.81
# 18  16-08-21  Windlas Biotech              405.95   24.40   15.73   24.27
# 19  16-08-21  Krsnaa Diagnost             1222.00   49.83  116.30   42.04
# 20  16-08-21      Devyani Int             1858.00   95.27  213.06   39.52
# 21  16-08-21     Exxaro Tiles              161.09   17.67    5.36   40.10
# 22  09-08-21      Rolex Rings              732.27  143.58  360.11   24.49
# 23  06-08-21    Glenmark Life             1513.00    0.98    0.87    4.61
# 24  29-07-21    Tatva Chintan              500.00    2.55    9.78   13.36
# 25  23-07-21           Zomato             9375.00   51.79   32.96    7.45
# 26  19-07-21        G R Infra              963.28   93.18   73.01    4.89
# 27  19-07-21    Clean Science             1546.00  156.37  206.43    9.00
# 28  07-07-21  India Pesticide              800.00    2.64    1.36    4.40
# 29  05-07-21    Krishna Inst.             2146.00    5.26    1.89    2.90
# 30  28-06-21      Dodla Dairy              521.00   84.88   73.26   11.34
# 31  24-06-21         Sona BLW             5550.00    1.57    0.22    0.66
# 32  24-06-21   Shyam Metalics              909.00   62.18  172.51    5.29
# 33  14-05-21  PowerGrid InvIT             7734.99    0.00    0.00    0.00
# 34  19-04-21    Macrotech Dev             2500.00    3.05    1.44    0.40
# 35  07-04-21     Barbeque Nat              453.60    0.00    0.00    0.00
# 36  30-03-21           Nazara              582.91   52.82  148.42   34.49
# 37  26-03-21   Suryoday Small              582.34    2.18    1.31    3.09
# 38  26-03-21  Kalyan Jeweller             1175.00    1.18    0.97    1.47
# 39  25-03-21        Craftsman              823.70    0.56    0.05    1.04
# 40  25-03-21    Laxmi Organic              600.00    1.13    0.73    4.41
# 41  24-03-21   Anupam Rasayan              760.00   30.80   62.06    4.62
# 42  19-03-21        Easy Trip              510.00    0.00    2.79   14.48
# 43  15-03-21        MTAR Tech              596.41   52.01  522.35   12.78
# 44  05-03-21          Heranba               60.00   25.98  108.72    4.82
# 45  26-02-21          Railtel              819.24   22.03   51.40    7.08
# 46  25-02-21           Nureca              100.00    0.24   17.10   74.29
# 47  05-02-21      Stove Kraft              412.63    8.02   32.72   26.04
# 48  03-02-21       Home First             1153.72   52.53   39.00    6.59
# 49  02-02-21    Indigo Paints             1170.56   96.21  115.76    6.50
# 50  29-01-21             IRFC             4633.00    0.89    0.52    1.59
# 51  01-01-21     Antony Waste              300.53    0.64    0.28    7.22
#
#     Issue_price  Listing_Open  Listing_Close  Listing_Gains(%)       CMP  \
# 0         662.0        700.00         840.00             26.89    641.45
# 1         197.0        530.00         488.60            148.02    639.85
# 2        1180.0       1311.00        1216.05              3.06  1,048.05
# 3        2150.0       1955.00        1564.15            -27.25  1,655.00
# 4         542.0        514.00         509.85             -5.93    441.05
# 5         980.0       1444.00        1202.90             22.74  1,210.50
# 6         163.0        575.00         603.75            270.40    429.35
# 7         577.0        548.00         545.25             -5.50    409.90
# 8        1125.0       2001.00        2206.70             96.15  2,252.00
# 9         712.0        697.50         699.65             -1.73    585.45
# 10        175.0        475.00         498.75            185.00    749.95
# 11        744.0        845.05         818.70             10.04    769.80
# 12        610.0        902.00         934.55             53.20  1,008.00
# 13        531.0        542.30         619.30             16.63    585.20
# 14        353.0        360.00         374.05              5.96    315.55
# 15        541.0        570.00         534.90             -1.13    585.25
# 16        570.0        471.00         531.30             -6.79    518.00
# 17       1618.0       1600.00        1500.10             -7.29    911.35
# 18        460.0        439.00         406.70            -11.59    281.85
# 19        954.0       1025.00         990.75              3.85    731.55
# 20         90.0        141.00         123.35             37.06    150.20
# 21        120.0        126.00         132.25             10.21    147.75
# 22        900.0       1249.00        1166.55             29.62  1,153.00
# 23        720.0        752.00         748.20              3.92    607.00
# 24       1083.0       2111.80        2310.25            113.32  2,609.10
# 25         76.0        115.00         125.85             65.59    142.00
# 26        837.0       1700.00        1746.80            108.70  1,800.00
# 27        900.0       1784.40        1585.20             76.13  2,620.30
# 28        296.0        360.00         335.45             13.33    300.65
# 29        825.0       1009.00        1096.80             32.95  1,391.10
# 30        428.0        550.00         609.10             42.31    567.60
# 31        291.0        302.40         362.85             24.69    762.95
# 32        306.0        380.00         375.85             22.83    312.30
# 33        100.0        104.00         102.98              2.98    120.05
# 34        486.0        439.00         463.15             -4.70  1,434.05
# 35        500.0        492.00         590.40             18.08  1,489.25
# 36       1101.0       1971.00        1576.80             43.22  2,339.00
# 37        305.0        274.75         276.20             -9.44    149.75
# 38         87.0         73.90          75.30            -13.45     69.80
# 39       1490.0       1440.00        1433.00             -3.83  2,289.70
# 40        130.0        173.00         164.60             26.62    430.50
# 41        555.0        534.70         525.90             -5.24    791.25
# 42        187.0        182.00         208.30             11.39    502.00
# 43        575.0        990.05        1082.25             88.22  2,320.00
# 44        627.0        900.00         812.25             29.55    685.00
# 45         94.0        109.00         121.40             29.15    118.75
# 46        400.0        634.95         666.65             66.66  1,531.25
# 47        385.0        498.00         445.95             15.83    950.70
# 48        518.0        612.15         527.40              1.81    850.00
# 49       1490.0       2607.50        3118.65            109.31  2,190.75
# 50         26.0         25.00          24.85             -4.42     23.35
# 51        315.0        430.00         407.25             29.29    285.65
#
#     Current_gains  year  month  day
# 0           -3.10    21     11   26
# 1          224.80    21     11   23
# 2          -11.18    21     11   18
# 3          -23.02    21     11   18
# 4          -18.63    21     11   15
# 5           23.52    21     11   15
# 6          163.40    21     11   15
# 7          -28.96    21     11   12
# 8          100.18    21     11   10
# 9          -17.77    21     10   11
# 10         328.54    21     10    1
# 11           3.47    21      9   24
# 12          65.25    21      9   14
# 13          10.21    21      9   14
# 14         -10.61    21      9    6
# 15           8.18    21      8   24
# 16          -9.12    21      8   23
# 17         -43.67    21      8   20
# 18         -38.73    21      8   16
# 19         -23.32    21      8   16
# 20          66.89    21      8   16
# 21          23.13    21      8   16
# 22          28.11    21      8    9
# 23         -15.69    21      8    6
# 24         140.91    21      7   29
# 25          86.84    21      7   23
# 26         115.05    21      7   19
# 27         191.14    21      7   19
# 28           1.57    21      7    7
# 29          68.62    21      7    5
# 30          32.62    21      6   28
# 31         162.18    21      6   24
# 32           2.06    21      6   24
# 33          20.05    21      5   14
# 34         195.07    21      4   19
# 35         197.85    21      4    7
# 36         112.44    21      3   30
# 37         -50.90    21      3   26
# 38         -19.77    21      3   26
# 39          53.67    21      3   25
# 40         231.15    21      3   25
# 41          42.57    21      3   24
# 42         168.45    21      3   19
# 43         303.48    21      3   15
# 44           9.25    21      3    5
# 45          26.33    21      2   26
# 46         282.81    21      2   25
# 47         146.94    21      2    5
# 48          64.09    21      2    3
# 49          47.03    21      2    2
# 50         -10.19    21      1   29
# 51          -9.32    21      1    1
